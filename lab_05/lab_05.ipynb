# %% [markdown]
# # Metody analizy danych. Lab 5. Biblioteka pandas, część 2

# %% [markdown]
# # 1. Indeksowanie i wybieranie danych
#
# O ile statystyki dla całej serii lub ramki danych są przydatne, o tyle często interesują nas różne podgrupy danych i ich własności co wymaga poznania (również poprzez analogię do poznanych już wycinków) mechanizmów pobierania i filtrowania danych w pandas. Najpierw załadujemy jednak niezbędne dane.
#
# W poniższych przykładach należy zaktualizować ścieżkę do danych, tak aby odpowiadała lokalnej strukturze przechowywania plików.

# %%
import pandas as pd
import os

# %%
DATAPATH = './DATA'

# %%
# dane pochdzą z serwisu Kaggle: https://www.kaggle.com/datasets/udaymalviya/bank-loan-data
df = pd.read_csv(os.path.join(DATAPATH, 'loan_data.csv'))

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
# 3                 0.44                         2.0           675
# 4                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                            Yes            0
# 2                             No            1
# 3                             No            1
# 4                             No            1

# %% [markdown]
# ## 1.1 Proste wybieranie kolumn danych z ramki

# %%
# wybieramy dane z jednej kolumny
df['person_gender']
# Out:
# 0        female
# 1        female
# 2        female
# 3        female
# 4          male
#           ...
# 44995      male
# 44996    female
# 44997      male
# 44998      male
# 44999      male
# Name: person_gender, Length: 45000, dtype: object

# %%
# w ten sam sposób możemy również wybrać dane z wielu kolumn, tym razem przekazujemy listę kolumn
df[['person_gender','person_education']]
# Out:
#       person_gender person_education
# 0            female           Master
# 1            female      High School
# 2            female      High School
# 3            female         Bachelor
# 4              male           Master
# ...             ...              ...
# 44995          male        Associate
# 44996        female        Associate
# 44997          male        Associate
# 44998          male         Bachelor
# 44999          male      High School
#
# [45000 rows x 2 columns]

# %%
# możemy również odwołać się do danych w kolumnie poprzez operator kropki
# w zależności od tego czy nazwy kolumn zawierają białe znaki czy nie
df.person_gender
# Out:
# 0        female
# 1        female
# 2        female
# 3        female
# 4          male
#           ...
# 44995      male
# 44996    female
# 44997      male
# 44998      male
# 44999      male
# Name: person_gender, Length: 45000, dtype: object

# %%
# pojedyncza kolumna to seria danych, tu możemy również podać indeks, lub wycinek
df['person_gender'][:5]
# Out:
# 0    female
# 1    female
# 2    female
# 3    female
# 4      male
# Name: person_gender, dtype: object

# %%
df[['person_gender','person_education']][:5]
# Out:
#   person_gender person_education
# 0        female           Master
# 1        female      High School
# 2        female      High School
# 3        female         Bachelor
# 4          male           Master

# %% [markdown]
# ## 1.2 Wybieranie danych poprzez `.loc`, `.iloc` oraz mapowanie tablicą boolowską
#
# `.loc` jest oparte o indeksowanie oparte na etykietach, ale można również przekazać tablice boolowską. Etykiety to inaczej wartości w kolumnie indeksu pandas series lub pandas data frame albo nazwy kolumn w pandas dataframe.

# %%
# dla ramki mamy dwa wymiary - wiersze oraz kolumny
df.loc[:, 'person_gender']
# Out:
# 0        female
# 1        female
# 2        female
# 3        female
# 4          male
#           ...
# 44995      male
# 44996    female
# 44997      male
# 44998      male
# 44999      male
# Name: person_gender, Length: 45000, dtype: object

# %%
# możemy również podać wartość tylko w jednym wymiarze
# tu szukamy wierszy, które w kolumnie indeks mają wartości 1 lub 2 lub 3
df.loc[[1,2,3]]
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
# 3                 0.44                         2.0           675
#
#   previous_loan_defaults_on_file  loan_status
# 1                            Yes            0
# 2                             No            1
# 3                             No            1

# %%
df.loc[:5, ['person_gender', 'person_income']]
# Out:
#   person_gender  person_income
# 0        female        71948.0
# 1        female        12282.0
# 2        female        12438.0
# 3        female        79753.0
# 4          male        66135.0
# 5        female        12951.0

# %%
# weźmy pod uwagę, że wartość dla pierwszego wymiaru loc to faktyczna wartość w kolumnie indeks
# a nie wartość indeksu elementów w tym indeksie
# poniżej przykład gdzie indeks został zmieniony na wartości rozpoczynające się od 1
df.index = range(1, df.shape[0] + 1)

# %%
df[:5]
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 1        22.0        female           Master        71948.0               0
# 2        21.0        female      High School        12282.0               0
# 3        25.0        female      High School        12438.0               3
# 4        23.0        female         Bachelor        79753.0               0
# 5        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 1                  RENT    35000.0    PERSONAL          16.02
# 2                   OWN     1000.0   EDUCATION          11.14
# 3              MORTGAGE     5500.0     MEDICAL          12.87
# 4                  RENT    35000.0     MEDICAL          15.23
# 5                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                 0.49                         3.0           561
# 2                 0.08                         2.0           504
# 3                 0.44                         3.0           635
# 4                 0.44                         2.0           675
# 5                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status
# 1                             No            1
# 2                            Yes            0
# 3                             No            1
# 4                             No            1
# 5                             No            1

# %%
# teraz sprawdzimy raz jeszcze jak działa loc z tymi samymi parametrami
df.loc[:5, ['person_gender', 'person_income']]
# Out:
#   person_gender  person_income
# 1        female        71948.0
# 2        female        12282.0
# 3        female        12438.0
# 4        female        79753.0
# 5          male        66135.0

# %% [markdown]
# **UWAGA!**
#
# Indeksowanie poprzez etykiety wykonywane jest z włączeniem wartości stop, co jest odmienne od tego jak działają klasyczne wycinki w Pythonie!.

# %% [markdown]
# Indeksowanie przez `.iloc` jest podobne do `.loc`, ale tutaj litera `i` oznacza indeks, więc zamiast wartości etykiet kolumn oraz wierszy podajemy indeksy.

# %%
# indeksy wierszy 0-4, indeks kolumn 2 i 3
df.iloc[:5, 2:4]
# Out:
#   person_education  person_income
# 1           Master        71948.0
# 2      High School        12282.0
# 3      High School        12438.0
# 4         Bachelor        79753.0
# 5           Master        66135.0

# %%
# podobnie jak w przypadku biblioteki numpy możemy w tych obszarach również podstawiać dane, np. zamienić kolumny kolejnością
# chociaż nie jest to zazwyczaj konieczne, gdyż możemy pobierać dane z ramki w dowolnej kolejności kolumn
# pobieramy kolumny w dowolnej kolejności
df.iloc[:, [2,1, 3]]
# Out:
#       person_education person_gender  person_income
# 1               Master        female        71948.0
# 2          High School        female        12282.0
# 3          High School        female        12438.0
# 4             Bachelor        female        79753.0
# 5               Master          male        66135.0
# ...                ...           ...            ...
# 44996        Associate          male        47971.0
# 44997        Associate        female        65800.0
# 44998        Associate          male        56942.0
# 44999         Bachelor          male        33164.0
# 45000      High School          male        51609.0
#
# [45000 rows x 3 columns]

# %%
# gdybyśmy jednak chcieli zamienić jes kolejnością w oryginalnej ramce to możemy np. wykorzystać do tego wektor
# aktualnych nazw kolumn z właściwości .columns
df.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='object')

# %%
# załóżmy, że chcemy zamienić miejscami kolumnę 2 i 3
# dla uproszczenia przechowamy wartości tych etykiet w liście Pythonowej
old_columns = list(df.columns)
new_column_order = old_columns[:1] + old_columns[2:0:-1] + old_columns[3:]
new_column_order
# Out:
# ['person_age',
#  'person_education',
#  'person_gender',
#  'person_income',
#  'person_emp_exp',
#  'person_home_ownership',
#  'loan_amnt',
#  'loan_intent',
#  'loan_int_rate',
#  'loan_percent_income',
#  'cb_person_cred_hist_length',
#  'credit_score',
#  'previous_loan_defaults_on_file',
#  'loan_status']

# %%
df = df.loc[:, new_column_order]

# %%
df.head()
# Out:
#    person_age person_education person_gender  person_income  person_emp_exp  \
# 1        22.0           Master        female        71948.0               0
# 2        21.0      High School        female        12282.0               0
# 3        25.0      High School        female        12438.0               3
# 4        23.0         Bachelor        female        79753.0               0
# 5        24.0           Master          male        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 1                  RENT    35000.0    PERSONAL          16.02
# 2                   OWN     1000.0   EDUCATION          11.14
# 3              MORTGAGE     5500.0     MEDICAL          12.87
# 4                  RENT    35000.0     MEDICAL          15.23
# 5                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                 0.49                         3.0           561
# 2                 0.08                         2.0           504
# 3                 0.44                         3.0           635
# 4                 0.44                         2.0           675
# 5                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status
# 1                             No            1
# 2                            Yes            0
# 3                             No            1
# 4                             No            1
# 5                             No            1

# %% [markdown]
# **Wybieranie danych poprzez tablice wartości boolowskich**
#
# Ta operacja jest zazwyczaj wykonywana w przypadku operacji filtrowania danych, gdzie nakładany jest warunek, na podstawie którego chcemy dane z ramki lub serii wybrać. Możemy tutaj wykorzystać operatory `|` (logiczne or), `&` (logiczne and) oraz `~` jako negację.

# %%
# zwracana jest tablica boolowska (tzw. mapowanie)
print(df['person_gender'] == 'female')

# teraz przykładamy mapowanie do danych poprzez przekazanie tego mapowania tak jak w przykładach wcześniejszych
df[df['person_gender'] == 'female']
# Out:
# 1         True
# 2         True
# 3         True
# 4         True
# 5        False
#          ...
# 44996    False
# 44997     True
# 44998    False
# 44999    False
# 45000    False
# Name: person_gender, Length: 45000, dtype: bool
#        person_age person_education person_gender  person_income  \
# 1            22.0           Master        female        71948.0
# 2            21.0      High School        female        12282.0
# 3            25.0      High School        female        12438.0
# 4            23.0         Bachelor        female        79753.0
# 6            21.0      High School        female        12951.0
# ...           ...              ...           ...            ...
# 44989        28.0        Associate        female        49170.0
# 44993        23.0         Bachelor        female        40925.0
# 44994        27.0      High School        female        35512.0
# 44995        24.0        Associate        female        31924.0
# 44997        37.0        Associate        female        65800.0
#
#        person_emp_exp person_home_ownership  loan_amnt      loan_intent  \
# 1                   0                  RENT    35000.0         PERSONAL
# 2                   0                   OWN     1000.0        EDUCATION
# 3                   3              MORTGAGE     5500.0          MEDICAL
# 4                   0                  RENT    35000.0          MEDICAL
# 6                   0                   OWN     2500.0          VENTURE
# ...               ...                   ...        ...              ...
# 44989               4                  RENT    10401.0  HOMEIMPROVEMENT
# 44993               0                  RENT     9000.0         PERSONAL
# 44994               4                  RENT     5000.0         PERSONAL
# 44995               2                  RENT    12229.0          MEDICAL
# 44997              17                  RENT     9000.0  HOMEIMPROVEMENT
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1              16.02                 0.49                         3.0
# 2              11.14                 0.08                         2.0
# 3              12.87                 0.44                         3.0
# 4              15.23                 0.44                         2.0
# 6               7.14                 0.19                         2.0
# ...              ...                  ...                         ...
# 44989          11.97                 0.21                         6.0
# 44993          11.01                 0.22                         4.0
# 44994          15.83                 0.14                         5.0
# 44995          10.70                 0.38                         4.0
# 44997          14.07                 0.14                        11.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 1               561                             No            1
# 2               504                            Yes            0
# 3               635                             No            1
# 4               675                             No            1
# 6               532                             No            1
# ...             ...                            ...          ...
# 44989           677                             No            1
# 44993           487                             No            1
# 44994           505                             No            1
# 44995           678                             No            1
# 44997           621                             No            1
#
# [20159 rows x 14 columns]

# %%
# więcej warunków - tu znowu mapowanie
(df['loan_amnt'] > 10000) & (df['person_income'] < 50000)
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 44996     True
# 44997    False
# 44998    False
# 44999     True
# 45000    False
# Length: 45000, dtype: bool

# %%
# a teraz dane
df[(df['loan_amnt'] > 10000) & (df['person_income'] < 50000)]
# Out:
#        person_age person_education person_gender  person_income  \
# 461          24.0        Associate          male        22684.0
# 494          23.0         Bachelor          male        43042.0
# 536          22.0      High School          male        38473.0
# 544          21.0      High School          male        42536.0
# 547          26.0         Bachelor        female        48929.0
# ...           ...              ...           ...            ...
# 44989        28.0        Associate        female        49170.0
# 44992        24.0      High School          male        37786.0
# 44995        24.0        Associate        female        31924.0
# 44996        27.0        Associate          male        47971.0
# 44999        29.0         Bachelor          male        33164.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 461                 0                   OWN    13000.0           PERSONAL
# 494                 1                  RENT    22250.0  DEBTCONSOLIDATION
# 536                 0                  RENT    21250.0  DEBTCONSOLIDATION
# 544                 0                  RENT    21000.0            VENTURE
# 547                 6                  RENT    21000.0            MEDICAL
# ...               ...                   ...        ...                ...
# 44989               4                  RENT    10401.0    HOMEIMPROVEMENT
# 44992               0              MORTGAGE    13500.0          EDUCATION
# 44995               2                  RENT    12229.0            MEDICAL
# 44996               6                  RENT    15000.0            MEDICAL
# 44999               4                  RENT    12000.0          EDUCATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 461             7.88                 0.57                         3.0
# 494            12.69                 0.52                         3.0
# 536            12.42                 0.55                         3.0
# 544            12.53                 0.49                         4.0
# 547             6.54                 0.43                         4.0
# ...              ...                  ...                         ...
# 44989          11.97                 0.21                         6.0
# 44992          13.43                 0.36                         4.0
# 44995          10.70                 0.38                         4.0
# 44996          15.66                 0.31                         3.0
# 44999          13.23                 0.36                         6.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 461             640                             No            1
# 494             678                             No            1
# 536             599                             No            1
# 544             687                             No            1
# 547             601                             No            1
# ...             ...                            ...          ...
# 44989           677                             No            1
# 44992           612                             No            1
# 44995           678                             No            1
# 44996           645                             No            1
# 44999           604                             No            1
#
# [1901 rows x 14 columns]

# %%
# a teraz dopełnienie tych danych poprzez wykorzystanie tego samego warunku oraz negacji
# został dodany dodatkowy nawias
df[~((df['loan_amnt'] > 10000) & (df['person_income'] < 50000))]
# Out:
#        person_age person_education person_gender  person_income  \
# 1            22.0           Master        female        71948.0
# 2            21.0      High School        female        12282.0
# 3            25.0      High School        female        12438.0
# 4            23.0         Bachelor        female        79753.0
# 5            24.0           Master          male        66135.0
# ...           ...              ...           ...            ...
# 44993        23.0         Bachelor        female        40925.0
# 44994        27.0      High School        female        35512.0
# 44997        37.0        Associate        female        65800.0
# 44998        33.0        Associate          male        56942.0
# 45000        24.0      High School          male        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 1                   0                  RENT    35000.0           PERSONAL
# 2                   0                   OWN     1000.0          EDUCATION
# 3                   3              MORTGAGE     5500.0            MEDICAL
# 4                   0                  RENT    35000.0            MEDICAL
# 5                   1                  RENT    35000.0            MEDICAL
# ...               ...                   ...        ...                ...
# 44993               0                  RENT     9000.0           PERSONAL
# 44994               4                  RENT     5000.0           PERSONAL
# 44997              17                  RENT     9000.0    HOMEIMPROVEMENT
# 44998               7                  RENT     2771.0  DEBTCONSOLIDATION
# 45000               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1              16.02                 0.49                         3.0
# 2              11.14                 0.08                         2.0
# 3              12.87                 0.44                         3.0
# 4              15.23                 0.44                         2.0
# 5              14.27                 0.53                         4.0
# ...              ...                  ...                         ...
# 44993          11.01                 0.22                         4.0
# 44994          15.83                 0.14                         5.0
# 44997          14.07                 0.14                        11.0
# 44998          10.02                 0.05                        10.0
# 45000          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 1               561                             No            1
# 2               504                            Yes            0
# 3               635                             No            1
# 4               675                             No            1
# 5               586                             No            1
# ...             ...                            ...          ...
# 44993           487                             No            1
# 44994           505                             No            1
# 44997           621                             No            1
# 44998           668                             No            1
# 45000           628                             No            1
#
# [43099 rows x 14 columns]

# %%
# jeżeli chcemy odfiltrować kolumnę na podstawie wielu wartości bardziej użyteczne i zwięzłe będzie
# wykorzystanie metody isin()
df['person_education'].isin(['Associate', 'High School'])
# Out:
# 1        False
# 2         True
# 3         True
# 4        False
# 5        False
#          ...
# 44996     True
# 44997     True
# 44998     True
# 44999    False
# 45000     True
# Name: person_education, Length: 45000, dtype: bool

# %%
# filtrowanie jest również możliwe przy wykorzystaniu obiektu callalbe (wywoływalnego),
# np. funkcji wbudowanej lub funkcji anonimowej (lambdy)
# oto przykłady

# tu następuje odwołanie do wartość str z tej serii, następnie użycie metody startswith('D') na każdej
# wartości tej serii, co zwraca tablicę boolowską
map_1 = df['loan_intent'].str.startswith('D')

# tutaj ten sam efekt, ale z wykorzystaniem apply (mapuje coś na każdy element obiektu iterowalnego) - tu mapujemy funkcję
# na każdą wartość z danej serii danych, dodatkowo przekazujemy argument 'D' do tej funkjci mapowanej
map_2 = df['loan_intent'].apply(str.startswith, args='D')

# i kolejny przypadek z wykorzystaniem map oraz funkcji anonimowej
map_3 = df['loan_intent'].map(lambda x: x.startswith('D'))

map_1, map_2, map_3
# Out:
# (1        False
#  2        False
#  3        False
#  4        False
#  5        False
#           ...
#  44996    False
#  44997    False
#  44998     True
#  44999    False
#  45000     True
#  Name: loan_intent, Length: 45000, dtype: bool,
#  1        False
#  2        False
#  3        False
#  4        False
#  5        False
#           ...
#  44996    False
#  44997    False
#  44998     True
#  44999    False
#  45000     True
#  Name: loan_intent, Length: 45000, dtype: bool,
#  1        False
#  2        False
#  3        False
#  4        False
#  5        False
#           ...
#  44996    False
#  44997    False
#  44998     True
#  44999    False
#  45000     True
#  Name: loan_intent, Length: 45000, dtype: bool)

# %%
# przyjmijmy scenariusz, w którym interesują nas rekordy, gdzie po odjęciu wartości
# pożyczki od dochodów pozostaje kwota > 50000

# możemy to obliczyć dość łatwo
print(df['person_income'] - df['loan_amnt'])

# teraz można na to nałożyć filtr
netto_income_mapping = (df['person_income'] - df['loan_amnt']) > 50000
print(netto_income_mapping)

# i przyłożyć do danych
df[netto_income_mapping]

# czy można to zrobić również z wykorzystaniem funkcji lambda?

# Funkcja lambda otrzymuje parametr dla każdej wartości zwracanej przez iterator dla obiektu iterowalnego
# na którym jest wywoływana. W poprzednim przypadku była to jedna seria danych więc do funkcji anonimowej trafiała
# pojedyncza wartość z serii. Teraz możemy spróbować z innym przykładem, gdzie do tej funkcji trafi więcej wartości.

# tutaj argumentem funkcji lambda jest cały rekord z ramki danych, możemy indeksować go w dowolny sposób
# który został przedstawiony wcześniej
df.apply(lambda x: (x['person_income'] - x['loan_amnt']) > 50000, axis=1)
# Out:
# 1        36948.0
# 2        11282.0
# 3         6938.0
# 4        44753.0
# 5        31135.0
#           ...
# 44996    32971.0
# 44997    56800.0
# 44998    54171.0
# 44999    21164.0
# 45000    44944.0
# Length: 45000, dtype: float64
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 44996    False
# 44997     True
# 44998     True
# 44999    False
# 45000    False
# Length: 45000, dtype: bool
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 44996    False
# 44997     True
# 44998     True
# 44999    False
# 45000    False
# Length: 45000, dtype: bool

# %% [markdown]
# ## 1.3 Wykorzystanie DataFrame.query
#
# Oprócz przykładów zaprezentowanych powyżej istnieje również metoda `query`, której wykorzystanie przy filtrach o dużej liczbie elemementów może być prostsze w zapisie.
#
# Przykłady w dokumentacji: https://pandas.pydata.org/docs/user_guide/indexing.html#the-query-method
#
# Poniżej kilka przykładów.

# %%
df.query('person_income > 100000')
# Out:
#        person_age person_education person_gender  person_income  \
# 9            24.0        Associate        female       100684.0
# 11           22.0      High School        female       102985.0
# 13           23.0         Bachelor          male       114860.0
# 14           26.0           Master          male       130713.0
# 15           23.0        Associate        female       138998.0
# ...           ...              ...           ...            ...
# 44948        42.0        Doctorate          male       705960.0
# 44966        31.0        Associate          male       100407.0
# 44973        43.0        Associate          male       184295.0
# 44983        26.0         Bachelor          male       130495.0
# 44991        31.0           Master          male       136832.0
#
#        person_emp_exp person_home_ownership  loan_amnt loan_intent  \
# 9                   3                  RENT    35000.0    PERSONAL
# 11                  0                  RENT    35000.0     VENTURE
# 13                  3                  RENT    35000.0     VENTURE
# 14                  0                  RENT    35000.0   EDUCATION
# 15                  0                  RENT    35000.0   EDUCATION
# ...               ...                   ...        ...         ...
# 44948              21              MORTGAGE    20686.0    PERSONAL
# 44966               9                  RENT    17783.0     VENTURE
# 44973              20              MORTGAGE    25000.0   EDUCATION
# 44983               0                  RENT     7622.0    PERSONAL
# 44991               9                  RENT    12319.0    PERSONAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 9               8.90                 0.35                         2.0
# 11             10.37                 0.34                         4.0
# 13              7.90                 0.30                         2.0
# 14             18.39                 0.27                         4.0
# 15              7.90                 0.25                         4.0
# ...              ...                  ...                         ...
# 44948          10.74                 0.03                        16.0
# 44966          19.80                 0.18                         8.0
# 44973          20.00                 0.14                        15.0
# 44983          15.58                 0.06                         5.0
# 44991          16.92                 0.09                         7.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 9               544                             No            1
# 11              621                             No            1
# 13              573                             No            1
# 14              708                             No            1
# 15              583                             No            0
# ...             ...                            ...          ...
# 44948           689                             No            1
# 44966           655                             No            1
# 44973           720                             No            1
# 44983           609                             No            1
# 44991           722                             No            1
#
# [10024 rows x 14 columns]

# %%
# tutaj również możemy używać łączników &, | oraz ~
display(df.query('person_education == "Doctorate" & person_age > 40'))
# poniższe działa jak isin(["Doctorate", "Master"])
df.query('person_education == ["Doctorate", "Master"] & person_age > 40')
# Out:
#        person_age person_education person_gender  person_income  \
# 29160        41.0        Doctorate        female       301153.0
# 29207        42.0        Doctorate          male        18097.0
# 29272        41.0        Doctorate          male        72894.0
# 29282        42.0        Doctorate          male        99557.0
# 29302        45.0        Doctorate          male        45165.0
# ...           ...              ...           ...            ...
# 43925        41.0        Doctorate          male       119343.0
# 44098        43.0        Doctorate          male        38812.0
# 44628        47.0        Doctorate          male        70131.0
# 44699        43.0        Doctorate        female        72213.0
# 44948        42.0        Doctorate          male       705960.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 29160              21              MORTGAGE     5000.0          EDUCATION
# 29207              19                   OWN     3500.0            MEDICAL
# 29272              17                  RENT    23800.0    HOMEIMPROVEMENT
# 29282              18                  RENT    22000.0  DEBTCONSOLIDATION
# 29302              25                  RENT    20000.0    HOMEIMPROVEMENT
# ...               ...                   ...        ...                ...
# 43925              19              MORTGAGE     7663.0            MEDICAL
# 44098              16                  RENT     8746.0            MEDICAL
# 44628              22                  RENT     1500.0            MEDICAL
# 44699              21              MORTGAGE    15000.0           PERSONAL
# 44948              21              MORTGAGE    20686.0           PERSONAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 29160           9.99                 0.02                        12.0
# 29207          11.01                 0.19                        11.0
# 29272           6.91                 0.33                        15.0
# 29282          10.99                 0.22                        12.0
# 29302          11.71                 0.44                        15.0
# ...              ...                  ...                         ...
# 43925          15.13                 0.06                        13.0
# 44098          15.62                 0.23                         9.0
# 44628          16.17                 0.02                        22.0
# 44699          11.01                 0.21                        14.0
# 44948          10.74                 0.03                        16.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 29160           721                             No            0
# 29207           569                             No            1
# 29272           755                             No            1
# 29282           608                            Yes            0
# 29302           579                             No            1
# ...             ...                            ...          ...
# 43925           709                             No            1
# 44098           722                             No            1
# 44628           735                             No            1
# 44699           726                             No            1
# 44948           689                             No            1
#
# [110 rows x 14 columns]
#        person_age person_education person_gender  person_income  \
# 29125        45.0           Master          male        96924.0
# 29132        43.0           Master        female       600812.0
# 29138        43.0           Master        female       480854.0
# 29154        41.0           Master        female       322597.0
# 29160        41.0        Doctorate        female       301153.0
# ...           ...              ...           ...            ...
# 44543        48.0           Master        female        65958.0
# 44628        47.0        Doctorate          male        70131.0
# 44659        44.0           Master        female        21702.0
# 44699        43.0        Doctorate        female        72213.0
# 44948        42.0        Doctorate          male       705960.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 29125              25                  RENT    35000.0            MEDICAL
# 29132              22              MORTGAGE    25000.0            VENTURE
# 29138              20              MORTGAGE    28000.0            VENTURE
# 29154              18              MORTGAGE    24000.0           PERSONAL
# 29160              21              MORTGAGE     5000.0          EDUCATION
# ...               ...                   ...        ...                ...
# 44543              24                  RENT     1169.0  DEBTCONSOLIDATION
# 44628              22                  RENT     1500.0            MEDICAL
# 44659              19                  RENT     1500.0           PERSONAL
# 44699              21              MORTGAGE    15000.0           PERSONAL
# 44948              21              MORTGAGE    20686.0           PERSONAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 29125          11.01                 0.36                        13.0
# 29132          12.61                 0.04                        14.0
# 29138           9.91                 0.06                        11.0
# 29154          10.37                 0.07                        11.0
# 29160           9.99                 0.02                        12.0
# ...              ...                  ...                         ...
# 44543          14.14                 0.02                        21.0
# 44628          16.17                 0.02                        22.0
# 44659          11.21                 0.07                        12.0
# 44699          11.01                 0.21                        14.0
# 44948          10.74                 0.03                        16.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 29125           566                             No            1
# 29132           685                             No            0
# 29138           619                             No            0
# 29154           683                            Yes            0
# 29160           721                             No            0
# ...             ...                            ...          ...
# 44543           704                             No            1
# 44628           735                             No            1
# 44659           767                             No            1
# 44699           726                             No            1
# 44948           689                             No            1
#
# [304 rows x 14 columns]

# %% [markdown]
# ## Zadania
#
# 1. Zamień nazwę kolumny `loan_amnt` na `loan_amount`.
#
# 2. Z ramki danych wykorzystanej w przykładach (loan) wyświetl:
# * a) tylko kolumny 'person_gender', 'person_age' oraz 'person_income',
# * b) wiersze od 1000 do 2000 włącznie (chodzi o kolejne wiersze w ramce, a nie wartość indeksu),
# * c) wiersze parzyste,
# * d) wiersze o parzystej wartości w kolumnie indeks,
# * e) pierwszą i ostatnią kolumnę.
#
# 3. Z tej samej ramki danych wyświetl dane wykorzystując filtry oparte o mapowanie:
# * a) tylko kobiety z wykształceniem 'Master' oraz 'Bachelor' i pożyczkami pomiędzy 50000 a 70000,
# * b) wszyscy mężczyźni z wykształceniem innym niż 'Master' oraz będący właścicielem lokalu (kolumna person_home_ownership = OWN),
# * c) wszystkie osoby z wartością `loan_percent_income` w przedziale od 0.4 do 0.6,
# * d) wszystkie wartości pożyczek, których kwota jest wielokrotnością liczby 10000.

# %%
# zmiana nazwy kolumny

df.rename(columns={"loan_amnt": "loan_amount"}, inplace=True)

print("Zadanie 1")
print(df.head())

# =========================
# WYŚWIETLANIE DANYCH
# =========================

print('/nZadanie2')

# a)
print("\na)")
print(df[["person_gender", "person_age", "person_income"]])

# b)
print("\nb)")
print(df.iloc[1000:2001])

# c)
print("\nc)")
print(df.iloc[::2])

# d)
print("\nd)")
print(df[df.index % 2 == 0])

# e)
print("\ne)")
print(df.iloc[:, [0, -1]])

# =========================
# FILTROWANIE
# =========================

print('/nZadanie3')

# a)

print("\nfilter a)")
print(
    df[
        (df["person_gender"] == "female") &
        (df["person_education"].isin(["Master", "Bachelor"])) &
        (df["loan_amount"].between(50000, 70000))
      ]
    )
# nie ma tak dużych pożyczek i tabela jest pusta
# b)

print("\nfilter b)")
print(
     df[
         (df["person_gender"] == "male") &
         (df["person_education"] != "Master") &
         (df["person_home_ownership"] == "OWN")
       ]
     )
# c)

print("\nfilter c)")
print(
    df[
        df["loan_percent_income"].between(0.4, 0.6)
         ]
    )
# d)

print("\nfilter d)")
print(
    df[
        df["loan_amount"] % 10000 == 0
        ]["loan_amount"]
    )
# Out:
# Zadanie 1
#    person_age person_education person_gender  person_income  person_emp_exp  \
# 1        22.0           Master        female        71948.0               0
# 2        21.0      High School        female        12282.0               0
# 3        25.0      High School        female        12438.0               3
# 4        23.0         Bachelor        female        79753.0               0
# 5        24.0           Master          male        66135.0               1
#
#   person_home_ownership  loan_amount loan_intent  loan_int_rate  \
# 1                  RENT      35000.0    PERSONAL          16.02
# 2                   OWN       1000.0   EDUCATION          11.14
# 3              MORTGAGE       5500.0     MEDICAL          12.87
# 4                  RENT      35000.0     MEDICAL          15.23
# 5                  RENT      35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 1                 0.49                         3.0           561
# 2                 0.08                         2.0           504
# 3                 0.44                         3.0           635
# 4                 0.44                         2.0           675
# 5                 0.53                         4.0           586
#
#   previous_loan_defaults_on_file  loan_status
# 1                             No            1
# 2                            Yes            0
# 3                             No            1
# 4                             No            1
# 5                             No            1
# /nZadanie2
#
# a)
#       person_gender  person_age  person_income
# 1            female        22.0        71948.0
# 2            female        21.0        12282.0
# 3            female        25.0        12438.0
# 4            female        23.0        79753.0
# 5              male        24.0        66135.0
# ...             ...         ...            ...
# 44996          male        27.0        47971.0
# 44997        female        37.0        65800.0
# 44998          male        33.0        56942.0
# 44999          male        29.0        33164.0
# 45000          male        24.0        51609.0
#
# [45000 rows x 3 columns]
#
# b)
#       person_age person_education person_gender  person_income  \
# 1001        23.0         Bachelor          male        30059.0
# 1002        24.0         Bachelor          male        68258.0
# 1003        21.0         Bachelor          male        60821.0
# 1004        25.0      High School          male        70432.0
# 1005        21.0         Bachelor        female        63842.0
# ...          ...              ...           ...            ...
# 1997        21.0           Master          male        37264.0
# 1998        24.0        Associate        female        36841.0
# 1999        24.0         Bachelor          male        37068.0
# 2000        22.0         Bachelor          male        37513.0
# 2001        23.0        Associate        female        36711.0
#
#       person_emp_exp person_home_ownership  loan_amount        loan_intent  \
# 1001               0              MORTGAGE       1375.0            MEDICAL
# 1002               2                  RENT      18000.0          EDUCATION
# 1003               0                  RENT      18000.0          EDUCATION
# 1004               6                  RENT      18000.0            VENTURE
# 1005               0                  RENT      18000.0            MEDICAL
# ...              ...                   ...          ...                ...
# 1997               0                  RENT      14000.0            MEDICAL
# 1998               4                  RENT      14000.0  DEBTCONSOLIDATION
# 1999               2              MORTGAGE       3075.0  DEBTCONSOLIDATION
# 2000               0                  RENT      14000.0            VENTURE
# 2001               0                  RENT      14000.0            MEDICAL
#
#       loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1001          11.11                 0.05                         4.0
# 1002          13.48                 0.26                         3.0
# 1003          14.74                 0.30                         2.0
# 1004          11.01                 0.26                         4.0
# 1005          19.69                 0.28                         2.0
# ...             ...                  ...                         ...
# 1997          10.65                 0.38                         2.0
# 1998           7.90                 0.38                         2.0
# 1999          11.01                 0.08                         4.0
# 2000           6.99                 0.37                         4.0
# 2001          11.26                 0.38                         3.0
#
#       credit_score previous_loan_defaults_on_file  loan_status
# 1001           506                             No            1
# 1002           671                             No            1
# 1003           530                             No            1
# 1004           609                             No            1
# 1005           678                             No            1
# ...            ...                            ...          ...
# 1997           545                             No            1
# 1998           538                             No            1
# 1999           521                            Yes            0
# 2000           595                             No            1
# 2001           554                             No            1
#
# [1001 rows x 14 columns]
#
# c)
#        person_age person_education person_gender  person_income  \
# 1            22.0           Master        female        71948.0
# 3            25.0      High School        female        12438.0
# 5            24.0           Master          male        66135.0
# 7            26.0         Bachelor        female        93471.0
# 9            24.0        Associate        female       100684.0
# ...           ...              ...           ...            ...
# 44991        31.0           Master          male       136832.0
# 44993        23.0         Bachelor        female        40925.0
# 44995        24.0        Associate        female        31924.0
# 44997        37.0        Associate        female        65800.0
# 44999        29.0         Bachelor          male        33164.0
#
#        person_emp_exp person_home_ownership  loan_amount      loan_intent  \
# 1                   0                  RENT      35000.0         PERSONAL
# 3                   3              MORTGAGE       5500.0          MEDICAL
# 5                   1                  RENT      35000.0          MEDICAL
# 7                   1                  RENT      35000.0        EDUCATION
# 9                   3                  RENT      35000.0         PERSONAL
# ...               ...                   ...          ...              ...
# 44991               9                  RENT      12319.0         PERSONAL
# 44993               0                  RENT       9000.0         PERSONAL
# 44995               2                  RENT      12229.0          MEDICAL
# 44997              17                  RENT       9000.0  HOMEIMPROVEMENT
# 44999               4                  RENT      12000.0        EDUCATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1              16.02                 0.49                         3.0
# 3              12.87                 0.44                         3.0
# 5              14.27                 0.53                         4.0
# 7              12.42                 0.37                         3.0
# 9               8.90                 0.35                         2.0
# ...              ...                  ...                         ...
# 44991          16.92                 0.09                         7.0
# 44993          11.01                 0.22                         4.0
# 44995          10.70                 0.38                         4.0
# 44997          14.07                 0.14                        11.0
# 44999          13.23                 0.36                         6.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 1               561                             No            1
# 3               635                             No            1
# 5               586                             No            1
# 7               701                             No            1
# 9               544                             No            1
# ...             ...                            ...          ...
# 44991           722                             No            1
# 44993           487                             No            1
# 44995           678                             No            1
# 44997           621                             No            1
# 44999           604                             No            1
#
# [22500 rows x 14 columns]
#
# d)
#        person_age person_education person_gender  person_income  \
# 2            21.0      High School        female        12282.0
# 4            23.0         Bachelor        female        79753.0
# 6            21.0      High School        female        12951.0
# 8            24.0      High School        female        95550.0
# 10           21.0      High School        female        12739.0
# ...           ...              ...           ...            ...
# 44992        24.0      High School          male        37786.0
# 44994        27.0      High School        female        35512.0
# 44996        27.0        Associate          male        47971.0
# 44998        33.0        Associate          male        56942.0
# 45000        24.0      High School          male        51609.0
#
#        person_emp_exp person_home_ownership  loan_amount        loan_intent  \
# 2                   0                   OWN       1000.0          EDUCATION
# 4                   0                  RENT      35000.0            MEDICAL
# 6                   0                   OWN       2500.0            VENTURE
# 8                   5                  RENT      35000.0            MEDICAL
# 10                  0                   OWN       1600.0            VENTURE
# ...               ...                   ...          ...                ...
# 44992               0              MORTGAGE      13500.0          EDUCATION
# 44994               4                  RENT       5000.0           PERSONAL
# 44996               6                  RENT      15000.0            MEDICAL
# 44998               7                  RENT       2771.0  DEBTCONSOLIDATION
# 45000               1                  RENT       6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 2              11.14                 0.08                         2.0
# 4              15.23                 0.44                         2.0
# 6               7.14                 0.19                         2.0
# 8              11.11                 0.37                         4.0
# 10             14.74                 0.13                         3.0
# ...              ...                  ...                         ...
# 44992          13.43                 0.36                         4.0
# 44994          15.83                 0.14                         5.0
# 44996          15.66                 0.31                         3.0
# 44998          10.02                 0.05                        10.0
# 45000          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 2               504                            Yes            0
# 4               675                             No            1
# 6               532                             No            1
# 8               585                             No            1
# 10              640                             No            1
# ...             ...                            ...          ...
# 44992           612                             No            1
# 44994           505                             No            1
# 44996           645                             No            1
# 44998           668                             No            1
# 45000           628                             No            1
#
# [22500 rows x 14 columns]
#
# e)
#        person_age  loan_status
# 1            22.0            1
# 2            21.0            0
# 3            25.0            1
# 4            23.0            1
# 5            24.0            1
# ...           ...          ...
# 44996        27.0            1
# 44997        37.0            1
# 44998        33.0            1
# 44999        29.0            1
# 45000        24.0            1
#
# [45000 rows x 2 columns]
# /nZadanie3
#
# filter a)
# Empty DataFrame
# Columns: [person_age, person_education, person_gender, person_income, person_emp_exp, person_home_ownership, loan_amount, loan_intent, loan_int_rate, loan_percent_income, cb_person_cred_hist_length, credit_score, previous_loan_defaults_on_file, loan_status]
# Index: []
#
# filter b)
#        person_age person_education person_gender  person_income  \
# 28           23.0      High School          male        14293.0
# 31           21.0      High School          male        14858.0
# 36           21.0        Associate          male        15150.0
# 44           23.0      High School          male       361547.0
# 58           23.0         Bachelor          male       333399.0
# ...           ...              ...           ...            ...
# 44354        25.0      High School          male        18772.0
# 44392        26.0        Associate          male        15288.0
# 44544        30.0      High School          male        24052.0
# 44684        23.0        Associate          male        23346.0
# 44826        22.0      High School          male        22538.0
#
#        person_emp_exp person_home_ownership  loan_amount      loan_intent  \
# 28                  0                   OWN       1400.0         PERSONAL
# 31                  0                   OWN       2000.0          MEDICAL
# 36                  0                   OWN       2500.0        EDUCATION
# 44                  0                   OWN      24250.0        EDUCATION
# 58                  1                   OWN      35000.0         PERSONAL
# ...               ...                   ...          ...              ...
# 44354               2                   OWN       4468.0          VENTURE
# 44392               2                   OWN       2690.0        EDUCATION
# 44544               8                   OWN       7000.0  HOMEIMPROVEMENT
# 44684               2                   OWN       4027.0          VENTURE
# 44826               1                   OWN       4913.0        EDUCATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 28              9.32                 0.10                         3.0
# 31             11.12                 0.13                         3.0
# 36              7.51                 0.17                         4.0
# 44             19.41                 0.07                         2.0
# 58             11.01                 0.10                         4.0
# ...              ...                  ...                         ...
# 44354          11.99                 0.24                         4.0
# 44392          10.96                 0.18                         4.0
# 44544          15.78                 0.29                         5.0
# 44684          15.01                 0.17                         4.0
# 44826          13.68                 0.22                         5.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 28              607                             No            0
# 31              589                             No            1
# 36              600                             No            1
# 44              637                            Yes            0
# 58              609                             No            0
# ...             ...                            ...          ...
# 44354           658                             No            1
# 44392           649                             No            1
# 44544           590                             No            1
# 44684           646                             No            1
# 44826           637                             No            1
#
# [1360 rows x 14 columns]
#
# filter c)
#        person_age person_education person_gender  person_income  \
# 1            22.0           Master        female        71948.0
# 3            25.0      High School        female        12438.0
# 4            23.0         Bachelor        female        79753.0
# 5            24.0           Master          male        66135.0
# 23           22.0           Master        female        79255.0
# ...           ...              ...           ...            ...
# 44904        25.0        Associate          male        43219.0
# 44941        29.0      High School          male        30046.0
# 44943        27.0           Master          male        48432.0
# 44967        26.0         Bachelor        female        36844.0
# 44987        34.0         Bachelor          male        41876.0
#
#        person_emp_exp person_home_ownership  loan_amount        loan_intent  \
# 1                   0                  RENT      35000.0           PERSONAL
# 3                   3              MORTGAGE       5500.0            MEDICAL
# 4                   0                  RENT      35000.0            MEDICAL
# 5                   1                  RENT      35000.0            MEDICAL
# 23                  0                  RENT      34000.0          EDUCATION
# ...               ...                   ...          ...                ...
# 44904               1                  RENT      22807.0            MEDICAL
# 44941               7                  RENT      12092.0           PERSONAL
# 44943               8                  RENT      20223.0            VENTURE
# 44967               0                  RENT      16000.0  DEBTCONSOLIDATION
# 44987              14                  RENT      19594.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1              16.02                 0.49                         3.0
# 3              12.87                 0.44                         3.0
# 4              15.23                 0.44                         2.0
# 5              14.27                 0.53                         4.0
# 23             17.58                 0.43                         4.0
# ...              ...                  ...                         ...
# 44904          12.67                 0.53                         5.0
# 44941          11.79                 0.40                         7.0
# 44943           6.83                 0.42                         8.0
# 44967          12.00                 0.43                         5.0
# 44987          12.03                 0.47                         8.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 1               561                             No            1
# 3               635                             No            1
# 4               675                             No            1
# 5               586                             No            1
# 23              691                             No            1
# ...             ...                            ...          ...
# 44904           668                             No            1
# 44941           535                             No            1
# 44943           650                             No            1
# 44967           620                             No            1
# 44987           707                             No            1
#
# [508 rows x 14 columns]
#
# filter d)
# 16       30000.0
# 37       30000.0
# 38       30000.0
# 39       30000.0
# 40       30000.0
#           ...
# 44911    20000.0
# 44945    30000.0
# 44954    10000.0
# 44963    10000.0
# 44985    20000.0
# Name: loan_amount, Length: 5126, dtype: float64
